# %% [markdown]
# # Template for analyzing the CLM5-PPE
# - Updated Jan 27, 2023
# - Daniel Kennedy, djk2120@ucar.edu

# %%
import numpy as np
import pandas as pd
import xarray as xr
import glob
import matplotlib.pyplot as plt
import cftime
import dask
import statsmodels.api as sm
import seaborn as sns

# %%
### import some analysis functions we wrote for this project
import sys ; sys.path.append("/glade/u/home/djk2120/ppe_tools")
from ppe_analysis.analysis import *

# %%
import panel as pn
import param
pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ## spin up some extra cores on CASPER

# %%
# Setup your PBSCluster
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client
ncores=1
nmem='10GB'
cluster = PBSCluster(
    cores=ncores, # The number of cores you want
    memory=nmem, # Amount of memory
    processes=1, # How many processes
    queue='casper', # The type of queue to utilize (/glade/u/apps/dav/opt/usr/bin/execcasper)
    local_directory='$TMPDIR', # Use your local directory
    resource_spec='select=1:ncpus='+str(ncores)+':mem='+nmem, # Specify resources
    project='P93300641', # Input your project ID here
    walltime='02:00:00', # Amount of wall time
    interface='ib0', # Interface to use
)

# Scale up
cluster.scale(30)

# Setup your client
client = Client(cluster)

# %%
client.cluster
# Out:
# Tab(children=(HTML(value='<div class="jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-outpu…

# %%
def get_files(exp):
    d='/glade/campaign/asp/djk2120/PPEn11/'
    files=sorted(glob.glob(d+exp+'/hist/*OAAT*h1*'))
    keys=['OAAT'+f.split('OAAT')[1].split('.')[0] for f in files]
    df=pd.read_csv(d+'csvs/oaat.csv')
    params=[]
    minmax=[]
    ix=[]
    for k in keys:
        p=df.param[df.key==k].values[0]
        m=df.minmax[df.key==k].values[0]
        if p!='test':
            params.append(p)
            minmax.append(m)
            ix.append(True)
        else:
            ix.append(False)

    files =np.array(files)[ix]
    keys=np.array(keys)[ix]

    appends={'key':keys,'param':params,'minmax':minmax}
    return files,appends

# %%
dvs=['TLAI']
dsets={}
for exp in ['CTL2010','C285','AF1855']:
    files,appends=get_files(exp)
    dsets[exp]=get_ds(files,['ens'],dvs=dvs,appends=appends)

# %%
lai_thresh=0.1
surv_thresh=0.7
npix={}
for exp in dsets:
    npix[exp]=(dsets[exp].TLAI.max(dim='time')>lai_thresh).groupby('pft').sum().compute()

# %%
vals = np.ones([2,4])
vals[0,:3]=np.array([223,194,125])/256
vals[1,:3]=np.array([50,130,50])/256
newcmp = matplotlib.colors.ListedColormap(vals)

# %%
npix0=npix['C285'].isel(ens=0)
surv = ((npix['C285']/npix0)>surv_thresh).sel(pft=1+np.arange(16))

fig,ax = plt.subplots(figsize=[12,3])
plt.pcolormesh(surv.T,cmap=newcmp)


cbar=plt.colorbar(ticks=[0, 1])
cbar.ax.set_yticklabels(['dead', 'alive']) 
cbar.ax.tick_params(labelsize=12)

plt.yticks([0,3,8,11,16])
ax.set_yticks([1.5,5.5,9.5,13.5], minor=True)
for y in [3,8,11]:
    plt.plot([0,len(ds.ens)],[y,y],':',color=[0.9,0.9,0.9],linewidth=0.5)
    
ax.yaxis.set_major_formatter(plt.NullFormatter())
ax.set_yticklabels(['NT','BT','Shrub','Grass'],minor=True);
plt.xlabel('Perturbation')
plt.title('C285 Survivability');

# %%
surv_thresh=0.8
surv=npix['CTL2010']>-1
for exp in npix:
    surv=surv&(npix[exp]/npix[exp].sel(ens=0)>surv_thresh)

# %%
surv=surv.sel(pft=1+np.arange(16))
surv.T.plot()

# %%
p0=xr.open_dataset('/glade/campaign/asp/djk2120/PPEn11/paramfiles/OAAT0000.nc')
multis={'CWD':'cwd_fcel',
        'FR':'fr_fcel',
        'LF':'lf_fcel',
        'KCN':'kc_nonmyc',
        'Q10':'q10_hr'}
def pvals(p):
    pp=p
    if p in multis:
        p=multis[p]
    ix=(ds.param==pp).values
    keys=ds.key.values[ix]
    if p in p0.data_vars:
        d='/glade/campaign/asp/djk2120/PPEn11/paramfiles/'
        files=[d+k+'.nc' for k in keys]
        def preprocess(ds):
            return ds[[p]]
        x=xr.open_mfdataset(files,combine='nested',concat_dim='ens',
                            parallel=True,preprocess=preprocess)
        x['ens']=ds.ens.values[ix]
        x['key']=xr.DataArray(keys,dims='ens')
        x['param']=xr.DataArray(np.tile(p,ix.sum()),dims='ens')

        dims=list(x[p].dims)
        dims.remove('ens')
        if len(dims)>0:
            x['val']=x[p].mean(dim=dims).compute()
        else:
            x['val']=x[p]
        x=x[['key','param','val']]
    else:
        d='/glade/campaign/asp/djk2120/PPEn11/namelist_mods/'
        vals=[]
        for k in keys:
            f=d+k+'.txt'
            with open(f) as file:
                lines = file.readlines()
            for line in lines:
                if p in line:
                    v=float(line.split('=')[1].split('\n')[0])
                    vals.append(v)
                    break
        x=xr.Dataset()
        x['val']=xr.DataArray(vals,dims='ens')
        x['ens']=ds.ens[ix]
        x['key']=xr.DataArray(keys,dims='ens')
        x['param']=xr.DataArray(np.tile(p,ix.sum()),dims='ens')
    return x

# %%
params=list(np.unique(ds.param))
params.remove('default')

# %%
for p in params[:10]:
    print(p)
    x=pvals(p)
# Out:
# C2_liq_Brun89
# CWD
# FR
# FUN_fracfixers
# KCN
# LF
# Q10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /glade/scratch/djk2120/ipykernel_181705/3055474485.py in <module>
#       1 for p in params[:10]:
#       2     print(p)
# ----> 3     x=pvals(p)
#
# /glade/scratch/djk2120/ipykernel_181705/1782485453.py in pvals(p)
#      42         x=xr.Dataset()
#      43         x['val']=xr.DataArray(vals,dims='ens')
# ---> 44         x['ens']=ds.ens[ix]
#      45         x['key']=xr.DataArray(keys,dims='ens')
#      46         x['param']=xr.DataArray(np.tile(p,ix.sum()),dims='ens')
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/dataset.py in __setitem__(self, key, value)
#    1563                     "a single key."
#    1564                 )
# -> 1565             self.update({key: value})
#    1566
#    1567     def _setitem_check(self, key, value):
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/dataset.py in update(self, other)
#    4248         Dataset.merge
#    4249         """
# -> 4250         merge_result = dataset_update_method(self, other)
#    4251         return self._replace(inplace=True, **merge_result._asdict())
#    4252
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/merge.py in dataset_update_method(dataset, other)
#     997         priority_arg=1,
#     998         indexes=indexes,  # type: ignore
# --> 999         combine_attrs="override",
#    1000     )
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/merge.py in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     633     coerced = coerce_pandas_values(objects)
#     634     aligned = deep_align(
# --> 635         coerced, join=join, copy=False, indexes=indexes, fill_value=fill_value
#     636     )
#     637     collected = collect_variables_and_indexes(aligned)
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/alignment.py in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid, fill_value)
#     439         indexes=indexes,
#     440         exclude=exclude,
# --> 441         fill_value=fill_value,
#     442     )
#     443
#
# /glade/work/djk2120/miniconda3/envs/ppe-py/lib/python3.7/site-packages/xarray/core/alignment.py in align(join, copy, indexes, exclude, fill_value, *objects)
#     347         if dim not in all_indexes and len(sizes) > 1:
#     348             raise ValueError(
# --> 349                 f"arguments without labels along dimension {dim!r} cannot be "
#     350                 f"aligned because they have different dimension sizes: {sizes!r}"
#     351             )
#
# ValueError: arguments without labels along dimension 'ens' cannot be aligned because they have different dimension sizes: {0, 2}

# %%
x
# Out:
# <xarray.Dataset>
# Dimensions:  (ens: 2)
# Coordinates:
#   * ens      (ens) int64 70 71
# Data variables:
#     val      (ens) float64 0.0005 0.1
#     key      (ens) <U8 'OAAT0070' 'OAAT0071'
#     param    (ens) <U15 'baseflow_scalar' 'baseflow_scalar'

# %%
xs=[pvals(p) for p in ['kmax','medlynslope','medlynintercept']]

# %%
xr.concat(xs,dim='ens')
# Out:
# <xarray.Dataset>
# Dimensions:  (ens: 15)
# Coordinates:
#   * ens      (ens) int64 159 160 117 118 390 402 414 ... 391 403 415 426 427 428
# Data variables:
#     key      (ens) <U8 'OAAT0159' 'OAAT0160' ... 'OAAT0437' 'OAAT0438'
#     param    (ens) <U15 'kmax' 'kmax' ... 'medlynintercept' 'medlynintercept'
#     val      (ens) float64 2.268e-09 3.792e-08 3.173 ... 6.25e+03 3.125e+03
# Attributes:
#     history:                    Fri Jun  3 13:42:04 2022: ncks -A -v crit_ons...
#     Conventions:                CF-1.0
#     title:                      Vegetation (Plant Function Type or PFT) const...
#     NCO:                        netCDF Operators version 5.0.3 (Homepage = ht...
#     nco_openmp_thread_number:   1
#     history_of_appended_files:  Fri Jun  3 13:42:04 2022: Appended file /glad...

# %%
for a,b in zip(x,s):
    print(a.mean().values,b.values)
# Out:
# 100.0 16
# 1.0 16
# 200000.0 11
# 100000.0 14
# 50000.0 16
# 25000.0 16
# 12500.0 16
# 6250.0 16
# 3125.0 16

# %%
plt.plot(ix,'.')

# %%
p=xr.open_dataset('/glade/campaign/asp/djk2120/PPEn11/paramfiles/OAAT0000.nc')

# %%
p.pftname
# Out:
# <xarray.DataArray 'pftname' (pft: 79)>
# array([b'not_vegetated                           ',
#        b'needleleaf_evergreen_temperate_tree     ',
#        b'needleleaf_evergreen_boreal_tree        ',
#        b'needleleaf_deciduous_boreal_tree        ',
#        b'broadleaf_evergreen_tropical_tree       ',
#        b'broadleaf_evergreen_temperate_tree      ',
#        b'broadleaf_deciduous_tropical_tree       ',
#        b'broadleaf_deciduous_temperate_tree      ',
#        b'broadleaf_deciduous_boreal_tree         ',
#        b'broadleaf_evergreen_shrub               ',
#        b'broadleaf_deciduous_temperate_shrub     ',
#        b'broadleaf_deciduous_boreal_shrub        ',
#        b'c3_arctic_grass                         ',
#        b'c3_non-arctic_grass                     ',
#        b'c4_grass                                ',
#        b'c3_crop                                 ',
#        b'c3_irrigated                            ',
#        b'temperate_corn                          ',
#        b'irrigated_temperate_corn                ',
#        b'spring_wheat                            ',
#        b'irrigated_spring_wheat                  ',
#        b'winter_wheat                            ',
#        b'irrigated_winter_wheat                  ',
#        b'temperate_soybean                       ',
#        b'irrigated_temperate_soybean             ',
#        b'barley                                  ',
#        b'irrigated_barley                        ',
#        b'winter_barley                           ',
#        b'irrigated_winter_barley                 ',
#        b'rye                                     ',
#        b'irrigated_rye                           ',
#        b'winter_rye                              ',
#        b'irrigated_winter_rye                    ',
#        b'cassava                                 ',
#        b'irrigated_cassava                       ',
#        b'citrus                                  ',
#        b'irrigated_citrus                        ',
#        b'cocoa                                   ',
#        b'irrigated_cocoa                         ',
#        b'coffee                                  ',
#        b'irrigated_coffee                        ',
#        b'cotton                                  ',
#        b'irrigated_cotton                        ',
#        b'datepalm                                ',
#        b'irrigated_datepalm                      ',
#        b'foddergrass                             ',
#        b'irrigated_foddergrass                   ',
#        b'grapes                                  ',
#        b'irrigated_grapes                        ',
#        b'groundnuts                              ',
#        b'irrigated_groundnuts                    ',
#        b'millet                                  ',
#        b'irrigated_millet                        ',
#        b'oilpalm                                 ',
#        b'irrigated_oilpalm                       ',
#        b'potatoes                                ',
#        b'irrigated_potatoes                      ',
#        b'pulses                                  ',
#        b'irrigated_pulses                        ',
#        b'rapeseed                                ',
#        b'irrigated_rapeseed                      ',
#        b'rice                                    ',
#        b'irrigated_rice                          ',
#        b'sorghum                                 ',
#        b'irrigated_sorghum                       ',
#        b'sugarbeet                               ',
#        b'irrigated_sugarbeet                     ',
#        b'sugarcane                               ',
#        b'irrigated_sugarcane                     ',
#        b'sunflower                               ',
#        b'irrigated_sunflower                     ',
#        b'miscanthus                              ',
#        b'irrigated_miscanthus                    ',
#        b'switchgrass                             ',
#        b'irrigated_switchgrass                   ',
#        b'tropical_corn                           ',
#        b'irrigated_tropical_corn                 ',
#        b'tropical_soybean                        ',
#        b'irrigated_tropical_soybean              '], dtype='|S40')
# Coordinates:
#     pftname  (pft) |S40 b'not_vegetated                           ' ... b'irr...
# Dimensions without coordinates: pft
# Attributes:
#     long_name:  Description of plant type
#     units:      unitless

# %%
ds.TLAI.sel(ens=0).max(dim='time').plot.line('.')

# %%
ds.TLAI.max(dim='time')
# Out:
# <xarray.DataArray 'TLAI' (ens: 493, gridcell: 400)>
# dask.array<nanmax-aggregate, shape=(493, 400), dtype=float32, chunksize=(1, 400), chunktype=numpy.ndarray>
# Dimensions without coordinates: ens, gridcell

# %%
lai=ds.TLAI.mean(dim=['time','gridcell']).compute()

# %%
lai.plot.line('.')
